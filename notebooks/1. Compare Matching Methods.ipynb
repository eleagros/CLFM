# %%
# %load_ext autoreload
# %autoreload 2
   
from clfm import clfm
import matplotlib.pyplot as plt

# %%
# path to the database root folder
path_database = '/home/elea/Documents/HORAO/DATABASES/2_CLFM/polarimetry'

# possible options include "polarimetry", "histology" and "custom"
# for custom, you should also provide the threshold (maximal distance, in pixel, for correct match) and 
# mm_per_pixel (the spatial resolution of your images)
type_alignment = 'polarimetry'

# create the project and load the image pairs
comparer = clfm.CLFMProject(path_database, type_alignment, threshold = None, mm_per_pixel = None)
comparer.prepare_imgs()

# %% [markdown]
# # Run the different methods and save the coordinates

# %% [markdown]
# ### 1. SIFT + MNN

# %%
sift_mnn_matcher = clfm.Matcher('sift', 'mnn', repetitions=comparer.repetitions)
sift_mnn_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [00:22<00:00,  1.49s/it]
# Processing time: 1.25 ± 0.08 s

# %% [markdown]
# ### 2. SiLK + MNN

# %%
silk_mnn_matcher = clfm.Matcher('silk', 'mnn', repetitions=comparer.repetitions)
silk_mnn_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [00:10<00:00,  1.41it/s]
# Processing time: 0.49 ± 0.03 s

# %% [markdown]
# ### 3. Superpoint + MNN

# %%
sp_mnn_matcher = clfm.Matcher('superpoint', 'mnn', repetitions=comparer.repetitions)
sp_mnn_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [00:29<00:00,  1.95s/it]
# Processing time: 1.73 ± 0.08 s

# %% [markdown]
# ### 4. SIFT + OANet

# %%
sift_oanet_matcher = clfm.Matcher('sift', 'oanet', repetitions=comparer.repetitions)
sift_oanet_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [00:47<00:00,  3.19s/it]
# Processing time: 2.97 ± 0.18 s

# %% [markdown]
# ### 5. SiLK + OANet

# %%
silk_oanet_matcher = clfm.Matcher('silk', 'oanet', repetitions=comparer.repetitions)
silk_oanet_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [00:36<00:00,  2.44s/it]
# Processing time: 2.23 ± 0.05 s

# %% [markdown]
# ### 6. Superpoint + OANet

# %%
sp_oanet_matcher = clfm.Matcher('superpoint', 'oanet', repetitions=comparer.repetitions)
sp_oanet_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [00:55<00:00,  3.71s/it]
# Processing time: 3.51 ± 0.28 s

# %% [markdown]
# ### 7. SP + SG

# %%
sp_sg_matcher = clfm.Matcher('superpoint', 'superglue', repetitions=comparer.repetitions)
sp_sg_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching:   0%|                                                                               | 0/15 [00:00<?, ?it/s]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:   7%|████▋                                                                  | 1/15 [00:04<00:57,  4.13s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  13%|█████████▍                                                             | 2/15 [00:08<00:52,  4.02s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  20%|██████████████▏                                                        | 3/15 [00:12<00:48,  4.01s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  27%|██████████████████▉                                                    | 4/15 [00:16<00:44,  4.00s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  33%|███████████████████████▋                                               | 5/15 [00:20<00:40,  4.00s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  40%|████████████████████████████▍                                          | 6/15 [00:24<00:36,  4.04s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  47%|█████████████████████████████████▏                                     | 7/15 [00:28<00:32,  4.07s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  53%|█████████████████████████████████████▊                                 | 8/15 [00:32<00:28,  4.04s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  60%|██████████████████████████████████████████▌                            | 9/15 [00:36<00:25,  4.18s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  67%|██████████████████████████████████████████████▋                       | 10/15 [00:40<00:20,  4.11s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  73%|███████████████████████████████████████████████████▎                  | 11/15 [00:44<00:16,  4.02s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  80%|████████████████████████████████████████████████████████              | 12/15 [00:48<00:11,  3.99s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  87%|████████████████████████████████████████████████████████████▋         | 13/15 [00:52<00:08,  4.09s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching:  93%|█████████████████████████████████████████████████████████████████▎    | 14/15 [00:57<00:04,  4.23s/it]
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/PROJECTS/2_CLFM/notebooks/tmp
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [01:01<00:00,  4.08s/it]
# Processing time: 3.86 ± 0.19 s

# %% [markdown]
# ### 8. Omniglue

# %%
# omniglue_matcher = clfm.Matcher('omniglue', 'omniglue', repetitions=comparer.repetitions)
# omniglue_matcher.run(comparer.parameters_dict, comparer.images)

# %% [markdown]
# ### 9. MatchAnything [eloftr]

# %%
matchyanything_matcher = clfm.Matcher('matchanything', 'eloftr', repetitions=comparer.repetitions)
matchyanything_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching:   0%|                                                                               | 0/15 [00:00<?, ?it/s]2026-02-27 18:24:00.477 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:00.615 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:00 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:00 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:00 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:03 hloc INFO] Matching images done using: 2.499s
# [2026/02/27 18:24:03 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:03 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:03 hloc INFO] RANSAC matches done using: 0.841s
# [2026/02/27 18:24:04 hloc INFO] Display matches done using: 0.776s
# [2026/02/27 18:24:04 hloc INFO] TOTAL time: 4.516s
# Local feature matching:   7%|████▋                                                                  | 1/15 [00:04<01:06,  4.76s/it]2026-02-27 18:24:05.238 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:05.368 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:05 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:05 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:05 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:07 hloc INFO] Matching images done using: 2.377s
# [2026/02/27 18:24:08 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:08 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:08 hloc INFO] RANSAC matches done using: 0.536s
# [2026/02/27 18:24:08 hloc INFO] Display matches done using: 0.387s
# [2026/02/27 18:24:08 hloc INFO] TOTAL time: 3.648s
# Local feature matching:  13%|█████████▍                                                             | 2/15 [00:08<00:54,  4.22s/it]2026-02-27 18:24:09.083 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:09.196 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:09 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:09 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:09 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:11 hloc INFO] Matching images done using: 2.775s
# [2026/02/27 18:24:12 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:12 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:12 hloc INFO] RANSAC matches done using: 0.816s
# [2026/02/27 18:24:13 hloc INFO] Display matches done using: 0.863s
# [2026/02/27 18:24:13 hloc INFO] TOTAL time: 4.792s
# Local feature matching:  20%|██████████████▏                                                        | 3/15 [00:13<00:54,  4.58s/it]2026-02-27 18:24:14.090 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:14.218 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:14 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:14 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:14 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:16 hloc INFO] Matching images done using: 2.677s
# [2026/02/27 18:24:17 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:17 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:17 hloc INFO] RANSAC matches done using: 0.762s
# [2026/02/27 18:24:18 hloc INFO] Display matches done using: 0.563s
# [2026/02/27 18:24:18 hloc INFO] TOTAL time: 4.354s
# Local feature matching:  27%|██████████████████▉                                                    | 4/15 [00:18<00:50,  4.57s/it]2026-02-27 18:24:18.658 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:18.800 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:18 hloc INFO] Loading matchanything_eloftr model done
# [2026/02/27 18:24:18 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:18 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:22 hloc INFO] Matching images done using: 3.356s
# [2026/02/27 18:24:23 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:23 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:23 hloc INFO] RANSAC matches done using: 0.897s
# [2026/02/27 18:24:23 hloc INFO] Display matches done using: 0.867s
# [2026/02/27 18:24:24 hloc INFO] TOTAL time: 5.495s
# Local feature matching:  33%|███████████████████████▋                                               | 5/15 [00:23<00:49,  4.98s/it]2026-02-27 18:24:24.373 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 2026-02-27 18:24:24.524 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:24 hloc INFO] Loading matchanything_eloftr model done
# [2026/02/27 18:24:24 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:24 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:27 hloc INFO] Matching images done using: 3.422s
# [2026/02/27 18:24:28 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:28 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:28 hloc INFO] RANSAC matches done using: 0.956s
# [2026/02/27 18:24:29 hloc INFO] Display matches done using: 0.936s
# [2026/02/27 18:24:30 hloc INFO] TOTAL time: 5.800s
# Local feature matching:  40%|████████████████████████████▍                                          | 6/15 [00:29<00:48,  5.35s/it]2026-02-27 18:24:30.425 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 2026-02-27 18:24:30.608 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:30 hloc INFO] Loading matchanything_eloftr model done
# [2026/02/27 18:24:30 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:30 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:35 hloc INFO] Matching images done using: 4.915s
# [2026/02/27 18:24:36 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:36 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:36 hloc INFO] RANSAC matches done using: 0.887s
# [2026/02/27 18:24:36 hloc INFO] Display matches done using: 0.552s
# [2026/02/27 18:24:37 hloc INFO] TOTAL time: 6.775s
# Local feature matching:  47%|█████████████████████████████████▏                                     | 7/15 [00:36<00:47,  5.89s/it]2026-02-27 18:24:37.420 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:37.540 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:37 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:37 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:37 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:40 hloc INFO] Matching images done using: 3.070s
# [2026/02/27 18:24:41 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:41 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:41 hloc INFO] RANSAC matches done using: 0.542s
# [2026/02/27 18:24:41 hloc INFO] Display matches done using: 0.362s
# [2026/02/27 18:24:41 hloc INFO] TOTAL time: 4.312s
# Local feature matching:  53%|█████████████████████████████████████▊                                 | 8/15 [00:41<00:38,  5.45s/it]2026-02-27 18:24:41.926 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# 2026-02-27 18:24:42.259 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:42 hloc INFO] Loading matchanything_eloftr model done
# [2026/02/27 18:24:42 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:42 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:45 hloc INFO] Matching images done using: 3.033s
# [2026/02/27 18:24:45 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:45 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:45 hloc INFO] RANSAC matches done using: 0.505s
# [2026/02/27 18:24:46 hloc INFO] Display matches done using: 0.312s
# [2026/02/27 18:24:46 hloc INFO] TOTAL time: 4.404s
# Local feature matching:  60%|██████████████████████████████████████████▌                            | 9/15 [00:46<00:31,  5.19s/it]2026-02-27 18:24:46.532 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:46.648 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:46 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:46 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:46 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:49 hloc INFO] Matching images done using: 3.075s
# [2026/02/27 18:24:50 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:50 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:50 hloc INFO] RANSAC matches done using: 0.730s
# [2026/02/27 18:24:50 hloc INFO] Display matches done using: 0.483s
# [2026/02/27 18:24:51 hloc INFO] TOTAL time: 4.655s
# Local feature matching:  67%|██████████████████████████████████████████████▋                       | 10/15 [00:50<00:25,  5.09s/it]2026-02-27 18:24:51.407 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:51.537 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:51 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:51 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:51 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:54 hloc INFO] Matching images done using: 3.079s
# [2026/02/27 18:24:55 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:24:55 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:24:55 hloc INFO] RANSAC matches done using: 0.632s
# [2026/02/27 18:24:55 hloc INFO] Display matches done using: 0.448s
# [2026/02/27 18:24:55 hloc INFO] TOTAL time: 4.508s
# Local feature matching:  73%|███████████████████████████████████████████████████▎                  | 11/15 [00:55<00:19,  4.97s/it]2026-02-27 18:24:56.123 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:24:56.253 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:24:56 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:24:56 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:24:56 hloc INFO] preprocessing is already resized
# [2026/02/27 18:24:59 hloc INFO] Matching images done using: 3.080s
# [2026/02/27 18:25:00 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:25:00 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:25:00 hloc INFO] RANSAC matches done using: 0.695s
# [2026/02/27 18:25:00 hloc INFO] Display matches done using: 0.512s
# [2026/02/27 18:25:00 hloc INFO] TOTAL time: 4.637s
# Local feature matching:  80%|████████████████████████████████████████████████████████              | 12/15 [01:00<00:14,  4.93s/it]2026-02-27 18:25:00.958 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:25:01.073 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:25:01 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:25:01 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:25:01 hloc INFO] preprocessing is already resized
# [2026/02/27 18:25:04 hloc INFO] Matching images done using: 3.190s
# [2026/02/27 18:25:05 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:25:05 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:25:05 hloc INFO] RANSAC matches done using: 1.020s
# [2026/02/27 18:25:05 hloc INFO] Display matches done using: 0.591s
# [2026/02/27 18:25:06 hloc INFO] TOTAL time: 5.160s
# Local feature matching:  87%|████████████████████████████████████████████████████████████▋         | 13/15 [01:05<00:10,  5.07s/it]2026-02-27 18:25:06.338 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:25:06.468 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:25:06 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:25:06 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:25:06 hloc INFO] preprocessing is already resized
# [2026/02/27 18:25:09 hloc INFO] Matching images done using: 3.301s
# [2026/02/27 18:25:10 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:25:10 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:25:10 hloc INFO] RANSAC matches done using: 0.790s
# [2026/02/27 18:25:11 hloc INFO] Display matches done using: 0.580s
# [2026/02/27 18:25:11 hloc INFO] TOTAL time: 5.042s
# Local feature matching:  93%|█████████████████████████████████████████████████████████████████▎    | 14/15 [01:11<00:05,  5.13s/it]2026-02-27 18:25:11.598 | INFO     | src.loftr.loftr_module.transformer:__init__:1441 - npe trainH,trainW,testH,testW: 832, 832, 832, 832
# 2026-02-27 18:25:11.731 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:25:11 hloc INFO] Loading matchanything_eloftr model done
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  None
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# RepVGG Block, identity =  BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# [2026/02/27 18:25:11 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:25:11 hloc INFO] preprocessing is already resized
# [2026/02/27 18:25:15 hloc INFO] Matching images done using: 3.289s
# [2026/02/27 18:25:15 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:25:15 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:25:15 hloc INFO] RANSAC matches done using: 0.754s
# [2026/02/27 18:25:16 hloc INFO] Display matches done using: 0.474s
# [2026/02/27 18:25:16 hloc INFO] TOTAL time: 4.876s
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [01:16<00:00,  5.08s/it]
# Processing time: 4.87 ± 0.71 s

# %% [markdown]
# ### 10. MatchAnything [roma]

# %%
matchyanything_matcher = clfm.Matcher('matchanything', 'roma', repetitions=comparer.repetitions)
matchyanything_matcher.run(comparer.parameters_dict, comparer.images)
# Out:
# Local feature matching:   0%|                                                                               | 0/15 [00:00<?, ?it/s]
# *****************cpu, True**************************
# 2026-02-27 18:25:21.477 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:25:21 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:25:21 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:25:21 hloc INFO] preprocessing is already resized
# [2026/02/27 18:26:05 hloc INFO] Matching images done using: 43.698s
# [2026/02/27 18:26:06 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:26:06 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:26:06 hloc INFO] RANSAC matches done using: 1.474s
# [2026/02/27 18:26:08 hloc INFO] Display matches done using: 1.751s
# [2026/02/27 18:26:08 hloc INFO] TOTAL time: 51.913s
# Local feature matching:   7%|████▋                                                                  | 1/15 [00:52<12:09, 52.14s/it]
# *****************cpu, True**************************
# 2026-02-27 18:26:11.902 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:26:11 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:26:11 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:26:11 hloc INFO] preprocessing is already resized
# [2026/02/27 18:26:58 hloc INFO] Matching images done using: 46.192s
# [2026/02/27 18:26:59 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:26:59 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:26:59 hloc INFO] RANSAC matches done using: 1.646s
# [2026/02/27 18:27:01 hloc INFO] Display matches done using: 1.362s
# [2026/02/27 18:27:01 hloc INFO] TOTAL time: 52.494s
# Local feature matching:  13%|█████████▍                                                             | 2/15 [01:44<11:22, 52.51s/it]
# *****************cpu, True**************************
# 2026-02-27 18:27:05.000 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:27:05 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:27:05 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:27:05 hloc INFO] preprocessing is already resized
# [2026/02/27 18:27:53 hloc INFO] Matching images done using: 48.124s
# [2026/02/27 18:27:55 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:27:55 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:27:55 hloc INFO] RANSAC matches done using: 1.916s
# [2026/02/27 18:27:56 hloc INFO] Display matches done using: 1.673s
# [2026/02/27 18:27:56 hloc INFO] TOTAL time: 55.350s
# Local feature matching:  20%|██████████████▏                                                        | 3/15 [02:40<10:47, 53.93s/it]
# *****************cpu, True**************************
# 2026-02-27 18:28:00.474 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:28:00 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:28:00 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:28:00 hloc INFO] preprocessing is already resized
# [2026/02/27 18:28:45 hloc INFO] Matching images done using: 44.968s
# [2026/02/27 18:28:47 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:28:47 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:28:47 hloc INFO] RANSAC matches done using: 1.705s
# [2026/02/27 18:28:48 hloc INFO] Display matches done using: 1.299s
# [2026/02/27 18:28:48 hloc INFO] TOTAL time: 51.424s
# Local feature matching:  27%|██████████████████▉                                                    | 4/15 [03:32<09:43, 53.03s/it]
# *****************cpu, True**************************
# 2026-02-27 18:28:52.494 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:28:52 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:28:52 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:28:52 hloc INFO] preprocessing is already resized
# [2026/02/27 18:29:39 hloc INFO] Matching images done using: 46.907s
# [2026/02/27 18:29:41 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:29:41 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:29:41 hloc INFO] RANSAC matches done using: 1.876s
# [2026/02/27 18:29:42 hloc INFO] Display matches done using: 1.402s
# [2026/02/27 18:29:42 hloc INFO] TOTAL time: 54.027s
# Local feature matching:  33%|███████████████████████▋                                               | 5/15 [04:26<08:54, 53.49s/it]
# *****************cpu, True**************************
# 2026-02-27 18:29:46.729 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:29:46 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:29:46 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:29:46 hloc INFO] preprocessing is already resized
# [2026/02/27 18:30:33 hloc INFO] Matching images done using: 46.911s
# [2026/02/27 18:30:35 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:30:35 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:30:35 hloc INFO] RANSAC matches done using: 1.562s
# [2026/02/27 18:30:36 hloc INFO] Display matches done using: 1.358s
# [2026/02/27 18:30:36 hloc INFO] TOTAL time: 53.645s
# Local feature matching:  40%|████████████████████████████▍                                          | 6/15 [05:20<08:02, 53.63s/it]
# *****************cpu, True**************************
# 2026-02-27 18:30:41.108 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:30:41 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:30:41 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:30:41 hloc INFO] preprocessing is already resized
# [2026/02/27 18:31:27 hloc INFO] Matching images done using: 46.095s
# [2026/02/27 18:31:28 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:31:28 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:31:28 hloc INFO] RANSAC matches done using: 1.705s
# [2026/02/27 18:31:30 hloc INFO] Display matches done using: 1.358s
# [2026/02/27 18:31:30 hloc INFO] TOTAL time: 53.396s
# Local feature matching:  47%|█████████████████████████████████▏                                     | 7/15 [06:14<07:09, 53.63s/it]
# *****************cpu, True**************************
# 2026-02-27 18:31:33.738 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:31:33 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:31:33 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:31:33 hloc INFO] preprocessing is already resized
# [2026/02/27 18:32:19 hloc INFO] Matching images done using: 45.528s
# [2026/02/27 18:32:20 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:32:20 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:32:20 hloc INFO] RANSAC matches done using: 1.536s
# [2026/02/27 18:32:22 hloc INFO] Display matches done using: 1.354s
# [2026/02/27 18:32:22 hloc INFO] TOTAL time: 51.659s
# Local feature matching:  53%|█████████████████████████████████████▊                                 | 8/15 [07:05<06:11, 53.07s/it]
# *****************cpu, True**************************
# 2026-02-27 18:32:26.029 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:32:26 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:32:26 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:32:26 hloc INFO] preprocessing is already resized
# [2026/02/27 18:33:12 hloc INFO] Matching images done using: 46.331s
# [2026/02/27 18:33:13 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:33:13 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:33:13 hloc INFO] RANSAC matches done using: 1.383s
# [2026/02/27 18:33:14 hloc INFO] Display matches done using: 0.985s
# [2026/02/27 18:33:14 hloc INFO] TOTAL time: 52.361s
# Local feature matching:  60%|██████████████████████████████████████████▌                            | 9/15 [07:58<05:17, 52.92s/it]
# *****************cpu, True**************************
# 2026-02-27 18:33:18.125 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:33:18 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:33:18 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:33:18 hloc INFO] preprocessing is already resized
# [2026/02/27 18:34:05 hloc INFO] Matching images done using: 46.993s
# [2026/02/27 18:34:06 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:34:06 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:34:06 hloc INFO] RANSAC matches done using: 1.460s
# [2026/02/27 18:34:07 hloc INFO] Display matches done using: 1.243s
# [2026/02/27 18:34:08 hloc INFO] TOTAL time: 52.898s
# Local feature matching:  67%|██████████████████████████████████████████████▋                       | 10/15 [08:51<04:24, 52.98s/it]
# *****************cpu, True**************************
# 2026-02-27 18:34:11.476 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:34:11 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:34:11 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:34:11 hloc INFO] preprocessing is already resized
# [2026/02/27 18:34:55 hloc INFO] Matching images done using: 44.052s
# [2026/02/27 18:34:56 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:34:56 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:34:56 hloc INFO] RANSAC matches done using: 1.415s
# [2026/02/27 18:34:58 hloc INFO] Display matches done using: 1.573s
# [2026/02/27 18:34:58 hloc INFO] TOTAL time: 50.425s
# Local feature matching:  73%|███████████████████████████████████████████████████▎                  | 11/15 [09:42<03:29, 52.27s/it]
# *****************cpu, True**************************
# 2026-02-27 18:35:01.879 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:35:01 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:35:01 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:35:01 hloc INFO] preprocessing is already resized
# [2026/02/27 18:35:44 hloc INFO] Matching images done using: 43.097s
# [2026/02/27 18:35:46 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:35:46 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:35:46 hloc INFO] RANSAC matches done using: 1.361s
# [2026/02/27 18:35:47 hloc INFO] Display matches done using: 1.219s
# [2026/02/27 18:35:47 hloc INFO] TOTAL time: 48.822s
# Local feature matching:  80%|████████████████████████████████████████████████████████              | 12/15 [10:31<02:33, 51.29s/it]
# *****************cpu, True**************************
# 2026-02-27 18:35:50.984 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:35:50 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:35:50 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:35:50 hloc INFO] preprocessing is already resized
# [2026/02/27 18:36:36 hloc INFO] Matching images done using: 45.522s
# [2026/02/27 18:36:37 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:36:37 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:36:37 hloc INFO] RANSAC matches done using: 1.390s
# [2026/02/27 18:36:39 hloc INFO] Display matches done using: 1.264s
# [2026/02/27 18:36:39 hloc INFO] TOTAL time: 51.388s
# Local feature matching:  87%|████████████████████████████████████████████████████████████▋         | 13/15 [11:22<01:42, 51.39s/it]
# *****************cpu, True**************************
# 2026-02-27 18:36:42.927 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:36:42 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:36:42 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:36:42 hloc INFO] preprocessing is already resized
# [2026/02/27 18:37:28 hloc INFO] Matching images done using: 45.179s
# [2026/02/27 18:37:29 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:37:29 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:37:29 hloc INFO] RANSAC matches done using: 1.431s
# [2026/02/27 18:37:31 hloc INFO] Display matches done using: 1.721s
# [2026/02/27 18:37:31 hloc INFO] TOTAL time: 51.904s
# Local feature matching:  93%|█████████████████████████████████████████████████████████████████▎    | 14/15 [12:15<00:51, 51.62s/it]
# *****************cpu, True**************************
# 2026-02-27 18:37:34.927 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/27 18:37:34 hloc INFO] Loading matchanything_roma model done
# [2026/02/27 18:37:34 hloc INFO] Matcher loaded from model/zoo
# [2026/02/27 18:37:34 hloc INFO] preprocessing is already resized
# [2026/02/27 18:38:19 hloc INFO] Matching images done using: 44.079s
# [2026/02/27 18:38:20 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/27 18:38:20 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/27 18:38:20 hloc INFO] RANSAC matches done using: 1.469s
# [2026/02/27 18:38:21 hloc INFO] Display matches done using: 1.262s
# [2026/02/27 18:38:21 hloc INFO] TOTAL time: 50.175s
# Local feature matching: 100%|██████████████████████████████████████████████████████████████████████| 15/15 [13:05<00:00, 52.36s/it]
# Processing time: 52.13 ± 1.59 s

# %% [markdown]
# # Align the images using bUnwarpJ and the previously obtained coordinates

# %%
combinations = (
    ('sift', 'mnn'),
    ('silk', 'mnn'),
    ('superpoint', 'mnn'),
    ('sift', 'oanet'),
    ('silk', 'oanet'),
    ('superpoint', 'oanet'),
    ('superpoint', 'superglue'),
    # ('omniglue', 'omniglue')
    ('matchanything', 'eloftr'),
    ('matchanything', 'roma')
)

# %%
from clfm import register, metrics

# if the ground truth maps have been generated manually
if type_alignment != 'histology':
    register.register_images(
        comparer.parameters_dict,
        ['gt']
    )
    pass
else:
    combinations = (*combinations, ('manual'))
# Out:
# Aligning images: 100%|████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 142.60it/s]

# %%
rmses, precisions = metrics.find_rmse(
    combinations,
    comparer.parameters_dict,
    comparer.images,
    comparer.type_alignment,
    comparer.threshold
)
# Out:
# Calculating RMSE: 100%|████████████████████████████████████████████████████████████████████████████| 15/15 [00:27<00:00,  1.86s/it]

# %%
rmses_agg, precisions_agg = metrics.aggregate_and_bootstrap_metrics(
    comparer.parameters_dict,
    combinations,
    type_alignment,
    comparer.threshold,
    comparer.mm_per_pixel,
    num_samples=1000
)

metrics.print_bootstrap_results(
    rmses_agg,
    precisions_agg,
)
# Out:
# Bootstrapping metrics: 100%|█████████████████████████████████████████████████████████████████████████| 9/9 [00:27<00:00,  3.06s/it]
# ===============================================================================================
# Combination               |   RMSE(px) ± error      |   RMSE(mm) ± error      |  Prec(%) ± error
# -----------------------------------------------------------------------------------------------
# sift + mnn                |     246.29 ± 2.70       |      12.31 ± 0.14       |     3.60 ± 0.44
# silk + mnn                |     243.69 ± 2.55       |      12.18 ± 0.13       |     6.19 ± 0.47
# superpoint + mnn          |     126.74 ± 7.93       |       6.34 ± 0.40       |    62.00 ± 2.43
# sift + oanet              |     152.73 ± 6.05       |       7.64 ± 0.30       |    24.94 ± 1.79
# silk + oanet              |     104.49 ± 2.71       |       5.22 ± 0.14       |    42.97 ± 0.96
# superpoint + oanet        |       6.55 ± 0.46       |       0.33 ± 0.02       |    97.32 ± 1.15
# superpoint + superglue    |       6.32 ± 0.69       |       0.32 ± 0.03       |    97.53 ± 1.15
# matchanything + eloftr    |       7.13 ± 0.12       |       0.36 ± 0.01       |    96.58 ± 0.27
# matchanything + roma      |       8.63 ± 0.26       |       0.43 ± 0.01       |    94.32 ± 0.17
# ===============================================================================================
